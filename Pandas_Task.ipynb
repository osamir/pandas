# %% [markdown]
# ***
# * **Name 1** =
# * **Name 2** =
# * **Name 3** =
# * **Name 4** =
# * **Name 5** =
# ***

# %% [markdown]
# | Q | Title                                                            | Points |
# |---|------------------------------------------------------------------|--------|
# | 1 | Heart   Disease Data Analysis using Pandas                       | 50     |
# | 2 | Exploratory   Data Analysis of Environmental Sensor Measurements | 50     |
# Total                                                            | 100    |
#
#
# You can use the Table of Content on the left side of this notebook to efficiently navigate within this documents.
#
# <font color='Red'><b>
# Packages that you are allowed to use: pandas and numpy
# </b></font>
#
# * All calculations can be performed exclusively using pandas. Nonetheless, for enhanced flexibility, numpy also serves as a viable alternative for some small tasks.

# %% [markdown]
# # **1. Heart Disease Data Analysis using Pandas (25 pts)**
#
# We analyze data collected from patients with heart disease to extract meaningful information. For more details about the dataset, refer to the Kaggle link provided: https://www.kaggle.com/imnikhilanand/heart-attack-prediction
#
# ![Img](https://storage.googleapis.com/kaggle-datasets-images/23651/30233/21d3eec8c2d5c04b7014f61ae3b516be/dataset-cover.jpg)
#
#
# | Column    | Description                                                |
# |-----------|------------------------------------------------------------|
# | age       | Age in years                                               |
# | sex       | Sex (1 = male; 0 = female)                                 |
# | cp        | Chest pain type                                           |
# | trestbps  | Resting blood pressure (in mm Hg on admission)            |
# | chol      | Serum cholestoral in mg/dl                                |
# | fbs       | Fasting blood sugar > 120 mg/dl (1 = true; 0 = false)     |
# | restecg   | Resting electrocardiographic results                       |
# | thalach   | Maximum heart rate achieved                               |
# | exang     | Exercise-induced angina (1 = yes; 0 = no)                 |
# | oldpeak   | ST depression induced by exercise relative to rest        |
# | slope     | The slope of the peak exercise ST segment                  |
# | ca        | Number of major vessels (0-3) colored by fluoroscopy       |
# | thal      | Thalassemia (3 = normal; 6 = fixed defect; 7 = reversible defect) |
# | num       | Diagnosis of heart disease (angiographic disease status)  |
#
# Please see [this link](https://www.kaggle.com/datasets/imnikhilanand/heart-attack-prediction) for a full description of the dataset attribute explanansions.
#
#
#
#
# **Tasks:**
#
# **Use 3 decimal places in all reports**
#
# **Report 1: Average Age of Patients**
# - Calculate and report the average age of patients in the dataset.
#
# **Report 2: Average Cholesterol Levels in Age Intervals**
# - Filter Data and select all patients in the age interval of [30-40).
# - Calculate and report the average cholesterol (chol) levels for this interval.
#
# **Report 3: Average Resting Blood Pressure in Extreme Cholesterol Levels**
# - How many patients that have data (non NaN) cholesterol in (chol) column?
# - Identify patients with the highest 30% cholesterol levels in the dataset [you many use [sort_values method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)].
# - Calculate and report the average resting blood pressure (trestbps) for patients in this group.
#
# **Report 4: Percentage of Men and Women with Positive Heart Disease Diagnosis**
# - Calculate and report the percentage of men with a positive diagnosis of heart disease (num=1) per all men in the dataset .

# %%
# =============================================================================
# Read the dataset
# =============================================================================
# The original dataset is available at the following link:
# https://www.kaggle.com/datasets/imnikhilanand/heart-attack-prediction
# For ease of access, the dataset has been uploaded on GitHub
url = 'https://raw.githubusercontent.com/osamir/pandas/refs/heads/main/heart_data.csv'

import pandas as pd


df = pd.read_csv(url)

# Display the first few rows of the DataFrame
display(df.head())
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   28    1   2     130.0  132.0  0.0      2.0    185.0    0.0      0.0
# 1   29    1   2     120.0  243.0  0.0      0.0    160.0    0.0      0.0
# 2   29    1   2     140.0    NaN  0.0      0.0    170.0    0.0      0.0
# 3   30    0   1     170.0  237.0  0.0      1.0    170.0    0.0      0.0
# 4   31    0   2     100.0  219.0  0.0      1.0    150.0    0.0      0.0
#
#    slope  ca  thal  num
# 0    NaN NaN   NaN    0
# 1    NaN NaN   NaN    0
# 2    NaN NaN   NaN    0
# 3    NaN NaN   6.0    0
# 4    NaN NaN   NaN    0

# %%
# Report 1: Average Age of Patients

# Report 2: Average Cholesterol Levels in Age Intervals

# Report 3: Average Resting Blood Pressure in Extreme Cholesterol Levels

# Report 4: Percentage of Men and Women with Positive Heart Disease Diagnosis

# %% [markdown]
# **Results should be as:**
#
# Average Age of Patients: 47.827
#
# Average Cholesterol [30-40): 239.630
#
# \# patients (non NaN) cholesterol in (chol) column: 271
#
# Average Resting Blood Pressure (High Cholesterol): 135.738
#
# Percentage of men with a positive diagnosis of heart disease: 88.679 %

# %% [markdown]
# ***
# **Your Contribution**
#
# Please make sure to add comments for the readiblity of your code.
#
# ***

# %% [markdown]
# <font color='Green'><b>Please provide detailed explanations of your code in this text block.</b></font>

# %% [markdown]
# # **2. Exploratory Data Analysis of Environmental Sensor Measurements (40 pts)**
#
# **Dataset:** You are provided with a dataset named "sensor_data.csv" containing measurements from various environmental sensors. The dataset consists of the following columns:
#
# - `time`: Timestamp of the measurement.
# - `power`: Power consumption (in watts).
# - `temp`: Temperature (in Celsius).
# - `humidity`: Humidity level (in percentage).
# - `light`: Light intensity (in lux).
# - `CO2`: Carbon dioxide concentration (in ppm).
# - `dust`: Dust concentration (in micrograms per cubic meter).
#
# **Tasks:**
# 1. **Data Loading and Initial Inspection:**
#    - Display the data types of each column.
#    - Display the number of unique values in the `time` column.
#
# 2. **Data Preprocessing:**
#    - Convert the `time` column to a [datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) format.
#    - Drop duplicate rows if any [drop_duplicates](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html).
#
# 3. **Data Analysis:**
#    - There seems to be an issue with the power consumption data where some values are recorded as -1. This is likely an error or an indication of **missing data**.
#    - Calculate and display the average power consumption on weekdays and weekends separately (to get the dayofweek from datetime you may use [Series.dt.dayofweek](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.dayofweek.html#pandas.Series.dt.dayofweek) and then you may use the method [apply](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html))
#    - Create a new column named `CO2_category` with categories: 'Low', 'Medium', and 'High' based on CO2 concentration as follows:
# $$
# \text{CO2_categories}(x) =
# \begin{cases}
# \text{Low} & \text{if } 0 \leq x < 500 \\
# \text{Medium} & \text{if } 500 \leq x < 1000 \\
# \text{High} & \text{if } x \geq 1000
# \end{cases}
# $$
# This mathematical representation describes how the categories 'Low,' 'Medium,' and 'High' are assigned based on the input value $x$.
#
#    - Calculate the mean power consumption for each CO2 category.
#
# ---

# %%
# =============================================================================
# Read the dataset
# =============================================================================

import pandas as pd

# Download the dataset from a specific URL
url = "https://raw.githubusercontent.com/osamir/pandas/refs/heads/main/sensor_data.csv"

# Load the data from 'sensor_data.csv' into a DataFrame.
df = pd.read_csv(url)

# Display the first few rows of the DataFrame
display(df.head())
# Out:
#                   time  power  temp  humidity  light  CO2   dust
# 0  2015-08-01 00:00:28    0.0    32        40      0  973  27.80
# 1  2015-08-01 00:00:58    0.0    32        40      0  973  27.09
# 2  2015-08-01 00:01:28    0.0    32        40      0  973  34.50
# 3  2015-08-01 00:01:58    0.0    32        40      0  973  28.43
# 4  2015-08-01 00:02:28    0.0    32        40      0  973  27.58

# %% [markdown]
# ***
# **Your Contribution**
#
# Please make sure to add comments for the readiblity of your code.
#
# ***

# %%
# Your Contribution

# 1- Data Loading and Initial Inspection:

#2- Data Preprocessing:

#3- Data Analysis:

# %% [markdown]
# <font color='Green'><b>Please provide detailed explanations of your code in this text block.</b></font>

# %%
# The End
